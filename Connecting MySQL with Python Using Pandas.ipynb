# %%
pip install sqlalchemy pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\janvi\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: pymysql in c:\users\janvi\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\janvi\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\janvi\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\janvi\anaconda3\lib\site-packages (1.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:%40TAGJanvi22@localhost/pandas"
)

# %%
import pandas as pd

# %%
df= pd.read_sql("select* from realworld_medical_dirty",engine)

# %%
df.head(20)
# Out:
#    Patient_ID   Age  Gender Blood_Pressure Cholesterol   BMI Smoker  \
# 0       P1000  55.0  FEMALE          120.0              35.4    Yes
# 1       P1001  65.0    Male          150.0       180.0  27.8    nan
# 2       P1002  45.0    Male          120.0       220.0  22.5     No
# 3       P1003  65.0    Male                      180.0  35.4     No
# 4       P1004  65.0    Male          120.0       300.0  40.1    nan
# 5       P1005  35.0  Female          130.0       200.0  35.4      N
# 6       P1006  45.0    MALE          150.0              22.5     No
# 7       P1009  65.0    MALE          130.0              35.4     No
# 8       P1010  55.0    MALE          140.0       220.0  30.0      Y
# 9       P1011  45.0    Male          120.0       300.0  35.4     No
# 10      P1013  65.0  FEMALE          120.0       250.0  27.8    nan
# 11      P1015  55.0    male          140.0       250.0  30.0      N
# 12      P1019  55.0  Female          150.0       250.0  40.1      Y
# 13      P1021  25.0    Male          160.0       180.0  27.8      N
# 14      P1022  55.0     nan          120.0       180.0  27.8     No
# 15      P1025  65.0  Female                      220.0  35.4    Yes
# 16      P1026  55.0     nan          130.0              27.8    Yes
# 17      P1029  45.0    Male          130.0              30.0      Y
# 18      P1030  45.0    MALE                             35.4    nan
# 19      P1031  35.0  FEMALE          150.0              40.1      N
#
#         Diagnosis Admission_Date               Notes
# 0   Heart Disease     2023-12-27
# 1            None     2023-01-01
# 2             nan     2023-12-14
# 3             nan     2023-07-09
# 4            None     2023-07-10  Follow-up required
# 5   Heart Disease     2023-11-08  Follow-up required
# 6            None     2023-04-27                 N/A
# 7        Diabetes     2023-02-13         Checkup due
# 8            None     2023-06-22         Checkup due
# 9             nan     2023-06-09                 N/A
# 10            nan     2023-11-13
# 11       Diabetes     2023-05-29         Checkup due
# 12            nan     2023-09-09  Follow-up required
# 13           None     2023-06-13  Follow-up required
# 14       Diabetes     2023-08-15                 N/A
# 15  Heart Disease     2023-02-16             Pending
# 16           None     2023-08-21         Checkup due
# 17  Heart Disease     2023-05-23                 N/A
# 18       Diabetes     2023-01-01         Checkup due
# 19           None     2023-02-23         Checkup due

# %%
# df.rename(columns={'oldname': 'newname'}, inplace=True)
# rename column

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      65 non-null     object
#  1   Age             65 non-null     float64
#  2   Gender          65 non-null     object
#  3   Blood_Pressure  65 non-null     object
#  4   Cholesterol     65 non-null     object
#  5   BMI             65 non-null     float64
#  6   Smoker          65 non-null     object
#  7   Diagnosis       65 non-null     object
#  8   Admission_Date  65 non-null     object
#  9   Notes           65 non-null     object
# dtypes: float64(2), object(8)
# memory usage: 5.2+ KB
#              Age        BMI
# count  65.000000  65.000000
# mean   48.384615  32.744615
# std    13.378729   6.084946
# min    25.000000  22.500000
# 25%    35.000000  27.800000
# 50%    55.000000  35.400000
# 75%    55.000000  40.100000
# max    65.000000  40.100000

# %%
df["Gender"]= df["Gender"].str.lower().str.strip()
df["Smoker"] = df["Smoker"].str.lower().str.strip()

# %%
df['Smoker'].unique()
# Out:
# array(['yes', 'nan', 'no', 'n', 'y'], dtype=object)

# %%
df['Smoker'] = (df['Smoker'].astype(str).str.lower().str.strip().replace({'y': 'yes','n': 'no','nan': pd.NA}).fillna('unknown'))

# %%
df['Diagnosis'].unique()
# Out:
# array(['Heart Disease', 'None', 'nan', 'Diabetes'], dtype=object)

# %%
df['Diagnosis']= (df["Diagnosis"].astype(str).str.lower().str.strip().replace({"none":pd.NA,'nan':pd.NA}).fillna("Undiagonised"))

# %%
df['Age'].isna()
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Blood_Pressure'] = pd.to_numeric(df['Blood_Pressure'])
df["Cholesterol"] = pd.to_numeric(df["Cholesterol"])

# %%
df["Blood_Pressure"] = df['Blood_Pressure'].fillna ( df["Blood_Pressure"].median())
df["Cholesterol"] =  df['Cholesterol'].fillna ( df["Cholesterol"].median())

# %%
df["Admission_Date"] = pd.to_datetime(df["Admission_Date"], errors="coerce")

# %%
df["Admission_year"] = df["Admission_Date"].dt.year
df["Admission_month"] = df["Admission_Date"].dt.month_name()
df["Admission_Day"] = df["Admission_Date"].dt.day
df["Admission_Dayname"] = df["Admission_Date"].dt.day_name()

# %%
df['Age_Group'] = pd.cut(df['Age'],bins=[0, 30, 45, 60, 100],labels=['Young', 'Adult', 'Middle-aged', 'Senior'])

# %%
df.groupby('Smoker')['Diagnosis'].value_counts(normalize=True)
#  It calculates the percentage distribution of each Diagnosis
# separately for Smoker = Yes and Smoker = No
# Out:
# Smoker   Diagnosis
# no       Undiagonised     0.407407
#          diabetes         0.333333
#          heart disease    0.259259
# unknown  Undiagonised     0.500000
#          diabetes         0.285714
#          heart disease    0.214286
# yes      Undiagonised     0.625000
#          heart disease    0.208333
#          diabetes         0.166667
# Name: proportion, dtype: float64

# %%
df.groupby('Gender')['Cholesterol'].mean()
# Out:
# Gender
# female    244.500000
# male      227.058824
# nan       220.000000
# Name: Cholesterol, dtype: float64

# %%
def bmi_category(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif bmi < 25:
        return 'Normal'
    elif bmi < 30:
        return 'Overweight'
    else:
        return 'Obese'

df['BMI_Category'] = df['BMI'].apply(bmi_category)

# %%
df['BMI_Category'].value_counts()
# Out:
# BMI_Category
# Obese         41
# Overweight    16
# Normal         8
# Name: count, dtype: int64

# %%
df['Admission_Weekday'] = df['Admission_Date'].dt.weekday
df['Admission_Weekday'].value_counts()
# Out:
# Admission_Weekday
# 6    13
# 1    12
# 0    10
# 3     9
# 5     8
# 2     7
# 4     6
# Name: count, dtype: int64

# %%
df.head(20)
# Out:
#    Patient_ID   Age   Gender  Blood_Pressure  Cholesterol   BMI   Smoker  \
# 0       P1000  55.0   female           120.0        220.0  35.4      yes
# 1       P1001  65.0     male           150.0        180.0  27.8  unknown
# 2       P1002  45.0     male           120.0        220.0  22.5       no
# 3       P1003  65.0     male           140.0        180.0  35.4       no
# 4       P1004  65.0     male           120.0        300.0  40.1  unknown
# 5       P1005  35.0   female           130.0        200.0  35.4       no
# 6       P1006  45.0     male           150.0        220.0  22.5       no
# 7       P1009  65.0     male           130.0        220.0  35.4       no
# 8       P1010  55.0     male           140.0        220.0  30.0      yes
# 9       P1011  45.0     male           120.0        300.0  35.4       no
# 10      P1013  65.0   female           120.0        250.0  27.8  unknown
# 11      P1015  55.0     male           140.0        250.0  30.0       no
# 12      P1019  55.0   female           150.0        250.0  40.1      yes
# 13      P1021  25.0     male           160.0        180.0  27.8       no
# 14      P1022  55.0  unknown           120.0        180.0  27.8       no
# 15      P1025  65.0   female           140.0        220.0  35.4      yes
# 16      P1026  55.0  unknown           130.0        220.0  27.8      yes
# 17      P1029  45.0     male           130.0        220.0  30.0      yes
# 18      P1030  45.0     male           140.0        220.0  35.4  unknown
# 19      P1031  35.0   female           150.0        220.0  40.1       no
#
#         Diagnosis                Admission_Date               Notes  \
# 0   heart disease 1970-01-01 00:00:00.000002023
# 1    undiagonised 1970-01-01 00:00:00.000002023
# 2    undiagonised 1970-01-01 00:00:00.000002023
# 3    undiagonised 1970-01-01 00:00:00.000002023
# 4    undiagonised 1970-01-01 00:00:00.000002023  Follow-up required
# 5   heart disease 1970-01-01 00:00:00.000002023  Follow-up required
# 6    undiagonised 1970-01-01 00:00:00.000002023                 N/A
# 7        diabetes 1970-01-01 00:00:00.000002023         Checkup due
# 8    undiagonised 1970-01-01 00:00:00.000002023         Checkup due
# 9    undiagonised 1970-01-01 00:00:00.000002023                 N/A
# 10   undiagonised 1970-01-01 00:00:00.000002023
# 11       diabetes 1970-01-01 00:00:00.000002023         Checkup due
# 12   undiagonised 1970-01-01 00:00:00.000002023  Follow-up required
# 13   undiagonised 1970-01-01 00:00:00.000002023  Follow-up required
# 14       diabetes 1970-01-01 00:00:00.000002023                 N/A
# 15  heart disease 1970-01-01 00:00:00.000002023             Pending
# 16   undiagonised 1970-01-01 00:00:00.000002023         Checkup due
# 17  heart disease 1970-01-01 00:00:00.000002023                 N/A
# 18       diabetes 1970-01-01 00:00:00.000002023         Checkup due
# 19   undiagonised 1970-01-01 00:00:00.000002023         Checkup due
#
#    Admission_month  Admission_Day Admission_Dayname  Admission_year  \
# 0          January              1          Thursday            1970
# 1          January              1          Thursday            1970
# 2          January              1          Thursday            1970
# 3          January              1          Thursday            1970
# 4          January              1          Thursday            1970
# 5          January              1          Thursday            1970
# 6          January              1          Thursday            1970
# 7          January              1          Thursday            1970
# 8          January              1          Thursday            1970
# 9          January              1          Thursday            1970
# 10         January              1          Thursday            1970
# 11         January              1          Thursday            1970
# 12         January              1          Thursday            1970
# 13         January              1          Thursday            1970
# 14         January              1          Thursday            1970
# 15         January              1          Thursday            1970
# 16         January              1          Thursday            1970
# 17         January              1          Thursday            1970
# 18         January              1          Thursday            1970
# 19         January              1          Thursday            1970
#
#       Age_Group  Admission_Weekday BMI_Category
# 0   Middle-aged                  3        Obese
# 1        Senior                  3   Overweight
# 2         Adult                  3       Normal
# 3        Senior                  3        Obese
# 4        Senior                  3        Obese
# 5         Adult                  3        Obese
# 6         Adult                  3       Normal
# 7        Senior                  3        Obese
# 8   Middle-aged                  3        Obese
# 9         Adult                  3        Obese
# 10       Senior                  3   Overweight
# 11  Middle-aged                  3        Obese
# 12  Middle-aged                  3        Obese
# 13        Young                  3   Overweight
# 14  Middle-aged                  3   Overweight
# 15       Senior                  3        Obese
# 16  Middle-aged                  3   Overweight
# 17        Adult                  3        Obese
# 18        Adult                  3        Obese
# 19        Adult                  3        Obese

# %%
# data = df.to_csv("Pandas_project_cleaned")

# %%
df['Notes'] = df['Notes'].str.lower().replace({"":"No Value","n/a": pd.NA}).fillna("Unknown")

# %%
df.head(20)
# Out:
#    Patient_ID   Age  Gender  Blood_Pressure  Cholesterol   BMI   Smoker  \
# 0       P1000  55.0  female           120.0        220.0  35.4      yes
# 1       P1001  65.0    male           150.0        180.0  27.8  unknown
# 2       P1002  45.0    male           120.0        220.0  22.5       no
# 3       P1003  65.0    male           140.0        180.0  35.4       no
# 4       P1004  65.0    male           120.0        300.0  40.1  unknown
# 5       P1005  35.0  female           130.0        200.0  35.4       no
# 6       P1006  45.0    male           150.0        220.0  22.5       no
# 7       P1009  65.0    male           130.0        220.0  35.4       no
# 8       P1010  55.0    male           140.0        220.0  30.0      yes
# 9       P1011  45.0    male           120.0        300.0  35.4       no
# 10      P1013  65.0  female           120.0        250.0  27.8  unknown
# 11      P1015  55.0    male           140.0        250.0  30.0       no
# 12      P1019  55.0  female           150.0        250.0  40.1      yes
# 13      P1021  25.0    male           160.0        180.0  27.8       no
# 14      P1022  55.0     nan           120.0        180.0  27.8       no
# 15      P1025  65.0  female           140.0        220.0  35.4      yes
# 16      P1026  55.0     nan           130.0        220.0  27.8      yes
# 17      P1029  45.0    male           130.0        220.0  30.0      yes
# 18      P1030  45.0    male           140.0        220.0  35.4  unknown
# 19      P1031  35.0  female           150.0        220.0  40.1       no
#
#         Diagnosis Admission_Date               Notes  Admission_year  \
# 0   heart disease     2023-12-27            no value            2023
# 1    Undiagonised     2023-01-01            no value            2023
# 2    Undiagonised     2023-12-14            no value            2023
# 3    Undiagonised     2023-07-09            no value            2023
# 4    Undiagonised     2023-07-10  follow-up required            2023
# 5   heart disease     2023-11-08  follow-up required            2023
# 6    Undiagonised     2023-04-27             Unknown            2023
# 7        diabetes     2023-02-13         checkup due            2023
# 8    Undiagonised     2023-06-22         checkup due            2023
# 9    Undiagonised     2023-06-09             Unknown            2023
# 10   Undiagonised     2023-11-13            no value            2023
# 11       diabetes     2023-05-29         checkup due            2023
# 12   Undiagonised     2023-09-09  follow-up required            2023
# 13   Undiagonised     2023-06-13  follow-up required            2023
# 14       diabetes     2023-08-15             Unknown            2023
# 15  heart disease     2023-02-16             pending            2023
# 16   Undiagonised     2023-08-21         checkup due            2023
# 17  heart disease     2023-05-23             Unknown            2023
# 18       diabetes     2023-01-01         checkup due            2023
# 19   Undiagonised     2023-02-23         checkup due            2023
#
#    Admission_month  Admission_Day Admission_Dayname    Age_Group BMI_Category  \
# 0         December             27         Wednesday  Middle-aged        Obese
# 1          January              1            Sunday       Senior   Overweight
# 2         December             14          Thursday        Adult       Normal
# 3             July              9            Sunday       Senior        Obese
# 4             July             10            Monday       Senior        Obese
# 5         November              8         Wednesday        Adult        Obese
# 6            April             27          Thursday        Adult       Normal
# 7         February             13            Monday       Senior        Obese
# 8             June             22          Thursday  Middle-aged        Obese
# 9             June              9            Friday        Adult        Obese
# 10        November             13            Monday       Senior   Overweight
# 11             May             29            Monday  Middle-aged        Obese
# 12       September              9          Saturday  Middle-aged        Obese
# 13            June             13           Tuesday        Young   Overweight
# 14          August             15           Tuesday  Middle-aged   Overweight
# 15        February             16          Thursday       Senior        Obese
# 16          August             21            Monday  Middle-aged   Overweight
# 17             May             23           Tuesday        Adult        Obese
# 18         January              1            Sunday        Adult        Obese
# 19        February             23          Thursday        Adult        Obese
#
#     Admission_Weekday
# 0                   2
# 1                   6
# 2                   3
# 3                   6
# 4                   0
# 5                   2
# 6                   3
# 7                   0
# 8                   3
# 9                   4
# 10                  0
# 11                  0
# 12                  5
# 13                  1
# 14                  1
# 15                  3
# 16                  0
# 17                  1
# 18                  6
# 19                  3

# %%
df["Patient_ID"] = df["Patient_ID"].replace({"P1025":"P1925"})

# %%
df.head(20)
# Out:
#    Patient_ID   Age  Gender  Blood_Pressure  Cholesterol   BMI   Smoker  \
# 0       P1000  55.0  female           120.0        220.0  35.4      yes
# 1       P1001  65.0    male           150.0        180.0  27.8  unknown
# 2       P1002  45.0    male           120.0        220.0  22.5       no
# 3       P1003  65.0    male           140.0        180.0  35.4       no
# 4       P1004  65.0    male           120.0        300.0  40.1  unknown
# 5       P1005  35.0  female           130.0        200.0  35.4       no
# 6       P1006  45.0    male           150.0        220.0  22.5       no
# 7       P1009  65.0    male           130.0        220.0  35.4       no
# 8       P1010  55.0    male           140.0        220.0  30.0      yes
# 9       P1011  45.0    male           120.0        300.0  35.4       no
# 10      P1013  65.0  female           120.0        250.0  27.8  unknown
# 11      P1015  55.0    male           140.0        250.0  30.0       no
# 12      P1019  55.0  female           150.0        250.0  40.1      yes
# 13      P1021  25.0    male           160.0        180.0  27.8       no
# 14      P1022  55.0     nan           120.0        180.0  27.8       no
# 15      P1925  65.0  female           140.0        220.0  35.4      yes
# 16      P1026  55.0     nan           130.0        220.0  27.8      yes
# 17      P1029  45.0    male           130.0        220.0  30.0      yes
# 18      P1030  45.0    male           140.0        220.0  35.4  unknown
# 19      P1031  35.0  female           150.0        220.0  40.1       no
#
#         Diagnosis Admission_Date               Notes  Admission_year  \
# 0   heart disease     2023-12-27            no value            2023
# 1    Undiagonised     2023-01-01            no value            2023
# 2    Undiagonised     2023-12-14            no value            2023
# 3    Undiagonised     2023-07-09            no value            2023
# 4    Undiagonised     2023-07-10  follow-up required            2023
# 5   heart disease     2023-11-08  follow-up required            2023
# 6    Undiagonised     2023-04-27             Unknown            2023
# 7        diabetes     2023-02-13         checkup due            2023
# 8    Undiagonised     2023-06-22         checkup due            2023
# 9    Undiagonised     2023-06-09             Unknown            2023
# 10   Undiagonised     2023-11-13            no value            2023
# 11       diabetes     2023-05-29         checkup due            2023
# 12   Undiagonised     2023-09-09  follow-up required            2023
# 13   Undiagonised     2023-06-13  follow-up required            2023
# 14       diabetes     2023-08-15             Unknown            2023
# 15  heart disease     2023-02-16             pending            2023
# 16   Undiagonised     2023-08-21         checkup due            2023
# 17  heart disease     2023-05-23             Unknown            2023
# 18       diabetes     2023-01-01         checkup due            2023
# 19   Undiagonised     2023-02-23         checkup due            2023
#
#    Admission_month  Admission_Day Admission_Dayname    Age_Group BMI_Category  \
# 0         December             27         Wednesday  Middle-aged        Obese
# 1          January              1            Sunday       Senior   Overweight
# 2         December             14          Thursday        Adult       Normal
# 3             July              9            Sunday       Senior        Obese
# 4             July             10            Monday       Senior        Obese
# 5         November              8         Wednesday        Adult        Obese
# 6            April             27          Thursday        Adult       Normal
# 7         February             13            Monday       Senior        Obese
# 8             June             22          Thursday  Middle-aged        Obese
# 9             June              9            Friday        Adult        Obese
# 10        November             13            Monday       Senior   Overweight
# 11             May             29            Monday  Middle-aged        Obese
# 12       September              9          Saturday  Middle-aged        Obese
# 13            June             13           Tuesday        Young   Overweight
# 14          August             15           Tuesday  Middle-aged   Overweight
# 15        February             16          Thursday       Senior        Obese
# 16          August             21            Monday  Middle-aged   Overweight
# 17             May             23           Tuesday        Adult        Obese
# 18         January              1            Sunday        Adult        Obese
# 19        February             23          Thursday        Adult        Obese
#
#     Admission_Weekday
# 0                   2
# 1                   6
# 2                   3
# 3                   6
# 4                   0
# 5                   2
# 6                   3
# 7                   0
# 8                   3
# 9                   4
# 10                  0
# 11                  0
# 12                  5
# 13                  1
# 14                  1
# 15                  3
# 16                  0
# 17                  1
# 18                  6
# 19                  3

# %%
df['BMI_Category'] = df['BMI_Category'].replace({"Normal":"Normal(standard)"}).str.lower()

# %%
df.head(20)
# Out:
#    Patient_ID   Age  Gender  Blood_Pressure  Cholesterol   BMI   Smoker  \
# 0       P1000  55.0  female           120.0        220.0  35.4      yes
# 1       P1001  65.0    male           150.0        180.0  27.8  unknown
# 2       P1002  45.0    male           120.0        220.0  22.5       no
# 3       P1003  65.0    male           140.0        180.0  35.4       no
# 4       P1004  65.0    male           120.0        300.0  40.1  unknown
# 5       P1005  35.0  female           130.0        200.0  35.4       no
# 6       P1006  45.0    male           150.0        220.0  22.5       no
# 7       P1009  65.0    male           130.0        220.0  35.4       no
# 8       P1010  55.0    male           140.0        220.0  30.0      yes
# 9       P1011  45.0    male           120.0        300.0  35.4       no
# 10      P1013  65.0  female           120.0        250.0  27.8  unknown
# 11      P1015  55.0    male           140.0        250.0  30.0       no
# 12      P1019  55.0  female           150.0        250.0  40.1      yes
# 13      P1021  25.0    male           160.0        180.0  27.8       no
# 14      P1022  55.0     nan           120.0        180.0  27.8       no
# 15      P1925  65.0  female           140.0        220.0  35.4      yes
# 16      P1026  55.0     nan           130.0        220.0  27.8      yes
# 17      P1029  45.0    male           130.0        220.0  30.0      yes
# 18      P1030  45.0    male           140.0        220.0  35.4  unknown
# 19      P1031  35.0  female           150.0        220.0  40.1       no
#
#         Diagnosis Admission_Date               Notes  Admission_year  \
# 0   heart disease     2023-12-27            no value            2023
# 1    Undiagonised     2023-01-01            no value            2023
# 2    Undiagonised     2023-12-14            no value            2023
# 3    Undiagonised     2023-07-09            no value            2023
# 4    Undiagonised     2023-07-10  follow-up required            2023
# 5   heart disease     2023-11-08  follow-up required            2023
# 6    Undiagonised     2023-04-27             Unknown            2023
# 7        diabetes     2023-02-13         checkup due            2023
# 8    Undiagonised     2023-06-22         checkup due            2023
# 9    Undiagonised     2023-06-09             Unknown            2023
# 10   Undiagonised     2023-11-13            no value            2023
# 11       diabetes     2023-05-29         checkup due            2023
# 12   Undiagonised     2023-09-09  follow-up required            2023
# 13   Undiagonised     2023-06-13  follow-up required            2023
# 14       diabetes     2023-08-15             Unknown            2023
# 15  heart disease     2023-02-16             pending            2023
# 16   Undiagonised     2023-08-21         checkup due            2023
# 17  heart disease     2023-05-23             Unknown            2023
# 18       diabetes     2023-01-01         checkup due            2023
# 19   Undiagonised     2023-02-23         checkup due            2023
#
#    Admission_month  Admission_Day Admission_Dayname    Age_Group  \
# 0         December             27         Wednesday  Middle-aged
# 1          January              1            Sunday       Senior
# 2         December             14          Thursday        Adult
# 3             July              9            Sunday       Senior
# 4             July             10            Monday       Senior
# 5         November              8         Wednesday        Adult
# 6            April             27          Thursday        Adult
# 7         February             13            Monday       Senior
# 8             June             22          Thursday  Middle-aged
# 9             June              9            Friday        Adult
# 10        November             13            Monday       Senior
# 11             May             29            Monday  Middle-aged
# 12       September              9          Saturday  Middle-aged
# 13            June             13           Tuesday        Young
# 14          August             15           Tuesday  Middle-aged
# 15        February             16          Thursday       Senior
# 16          August             21            Monday  Middle-aged
# 17             May             23           Tuesday        Adult
# 18         January              1            Sunday        Adult
# 19        February             23          Thursday        Adult
#
#         BMI_Category  Admission_Weekday
# 0              obese                  2
# 1         overweight                  6
# 2   normal(standard)                  3
# 3              obese                  6
# 4              obese                  0
# 5              obese                  2
# 6   normal(standard)                  3
# 7              obese                  0
# 8              obese                  3
# 9              obese                  4
# 10        overweight                  0
# 11             obese                  0
# 12             obese                  5
# 13        overweight                  1
# 14        overweight                  1
# 15             obese                  3
# 16        overweight                  0
# 17             obese                  1
# 18             obese                  6
# 19             obese                  3

# %%
df.columns = df.iloc[0]   # set first row as header
df = df[1:] 
df,reset_index

# %%
df.head(10)
# Out:
# 2   P1002  45.0    male  120.0  220.0  22.5       no   Undiagonised  \
# 2   P1002  45.0    male  120.0  220.0  22.5       no   Undiagonised
# 3   P1003  65.0    male  140.0  180.0  35.4       no   Undiagonised
# 4   P1004  65.0    male  120.0  300.0  40.1  unknown   Undiagonised
# 5   P1005  35.0  female  130.0  200.0  35.4       no  heart disease
# 6   P1006  45.0    male  150.0  220.0  22.5       no   Undiagonised
# 7   P1009  65.0    male  130.0  220.0  35.4       no       diabetes
# 8   P1010  55.0    male  140.0  220.0  30.0      yes   Undiagonised
# 9   P1011  45.0    male  120.0  300.0  35.4       no   Undiagonised
# 10  P1013  65.0  female  120.0  250.0  27.8  unknown   Undiagonised
# 11  P1015  55.0    male  140.0  250.0  30.0       no       diabetes
#
# 2  2023-12-14 00:00:00            no value  2023  December  14   Thursday  \
# 2           2023-12-14            no value  2023  December  14   Thursday
# 3           2023-07-09            no value  2023      July   9     Sunday
# 4           2023-07-10  follow-up required  2023      July  10     Monday
# 5           2023-11-08  follow-up required  2023  November   8  Wednesday
# 6           2023-04-27             Unknown  2023     April  27   Thursday
# 7           2023-02-13         checkup due  2023  February  13     Monday
# 8           2023-06-22         checkup due  2023      June  22   Thursday
# 9           2023-06-09             Unknown  2023      June   9     Friday
# 10          2023-11-13            no value  2023  November  13     Monday
# 11          2023-05-29         checkup due  2023       May  29     Monday
#
# 2         Adult  normal(standard)  3
# 2         Adult  normal(standard)  3
# 3        Senior             obese  6
# 4        Senior             obese  0
# 5         Adult             obese  2
# 6         Adult  normal(standard)  3
# 7        Senior             obese  0
# 8   Middle-aged             obese  3
# 9         Adult             obese  4
# 10       Senior        overweight  0
# 11  Middle-aged             obese  0
